# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
pwd
# Out:
# 'C:\\Users\\Orakzai\\OneDrive - University of Essex\\Micorwave Imaging'

# %%
# Load the data
Data = pd.read_csv('C:\\Users\\Orakzai\\OneDrive - University of Essex\\Micorwave Imaging\\Aug_Data_10cases/integrated_and_labeled_dataset.csv')


## Encode the 'Label' column
label_encoder = LabelEncoder()
Data['Label'] = label_encoder.fit_transform(Data['Label'])

# Separate features and target variable
X = Data.drop('Label', axis=1)
y = Data['Label']

# Normalize the features
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# %%
# Split the data into training and testing sets
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Initialize LazyClassifier to fit all models
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# Fit all models and print performance table
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# Display the performance table
models
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [00:31<00:01,  1.54s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001314 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 608
# [LightGBM] [Info] Number of data points in the train set: 8844, number of used features: 5
# [LightGBM] [Info] Start training from score -1.605939
# [LightGBM] [Info] Start training from score -1.609325
# [LightGBM] [Info] Start training from score -1.622985
# [LightGBM] [Info] Start training from score -1.599201
# [LightGBM] [Info] Start training from score -1.609890
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:32<00:00,  1.12s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ...

# %%
# Assuming 'models' contains your model performance metrics
models.to_csv('C:\\Users\\orakz\\OneDrive - University of Essex\\Micorwave Imaging\\Aug_Data_10cases\model_performance.csv')
